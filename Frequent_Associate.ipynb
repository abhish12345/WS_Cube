# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',200)

# %%
dataset = pd.read_csv('groceries - groceries.csv')

# %%
dataset.head(3)
# Out:
#    Item(s)          Item 1               Item 2     Item 3       Item 4  \
# 0        4    citrus fruit  semi-finished bread  margarine  ready soups
# 1        3  tropical fruit               yogurt     coffee          NaN
# 2        1      whole milk                  NaN        NaN          NaN
#
#   Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23 Item 24 Item 25 Item 26  \
# 0    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
#
#   Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 33 columns]

# %%
dataset.shape
# Out:
# (9835, 33)

# %%
dataset.drop(columns='Item(s)',inplace=True)

# %%
for i in range(13, 34):
    dataset.drop(columns=f'Item {i}', inplace=True, errors='ignore')

# %%
market= []
for i in range(0,dataset.shape[0]):
    cus = []
    for j in dataset.columns:
        if type(dataset[j][i])==str:
            cus.append(dataset[j][i])
    market.append(cus)

# %%
l = []
for i in market:
    for j in i:
        l.append(j)

# %%
import collections

# %%
p=collections.Counter(l)

# %%
d = {'Item Name': p.keys(),'values':p.values()}

# %%
pd.DataFrame(d).sort_values(by=["values"],ascending=False)
# Out:
#                      Item Name  values
# 7                   whole milk    2513
# 11            other vegetables    1903
# 17                  rolls/buns    1797
# 31                        soda    1664
# 5                       yogurt    1369
# 42             root vegetables    1072
# 24               bottled water    1057
# 4               tropical fruit    1032
# 50                     sausage     924
# 52               shopping bags     895
# 39                      pastry     864
# 0                 citrus fruit     814
# 19                bottled beer     761
# 49                 canned beer     752
# 8                    pip fruit     744
# 35                  newspapers     734
# 60          whipped/sour cream     703
# 34       fruit/vegetable juice     647
# 51                 brown bread     628
# 65               domestic eggs     613
# 30                 frankfurter     580
# 58                        pork     567
# 2                    margarine     559
# ...

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(df,min_support=0.05,use_colnames=True,max_len=3).sort_values(by=['support'])
# Out:
#      support                        itemsets
# 13  0.052466                          (beef)
# 12  0.053177                          (curd)
# 8   0.055414                        (butter)
# 29  0.055618        (rolls/buns, whole milk)
# 27  0.055719            (yogurt, whole milk)
# 4   0.056024                        (coffee)
# 1   0.056838                     (margarine)
# 25  0.057651                          (pork)
# 15  0.058973                   (frankfurter)
# 26  0.062328                 (domestic eggs)
# 23  0.063854                   (brown bread)
# 17  0.065785         (fruit/vegetable juice)
# 24  0.071479            (whipped/sour cream)
# 16  0.074631                    (newspapers)
# 28  0.074835  (whole milk, other vegetables)
# 6   0.075648                     (pip fruit)
# 20  0.076462                   (canned beer)
# 10  0.077377                  (bottled beer)
# 0   0.082766                  (citrus fruit)
# 18  0.087850                        (pastry)
# ...

# %%
use
