# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=250,noise=0.05)

# %%
x.shape
# Out:
# (250, 2)

# %%
y.shape
# Out:
# (250,)

# %%
df = {'data1':x[:,0],'data2':x[:,1]}

# %%
dataset = pd.DataFrame(df)

# %%
dataset.head()
# Out:
#       data1     data2
# 0  0.148384  0.016103
# 1  0.395620 -0.291693
# 2  0.129239 -0.010090
# 3  0.381917  0.964549
# 4 -0.870123  0.621002

# %%
sns.scatterplot(x='data1',y='data2',data=dataset)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.2,min_samples=3)
dataset['Predict']=db.fit_predict(dataset)

# %%
dataset.head()
# Out:
#       data1     data2  Predict
# 0  0.148384  0.016103        0
# 1  0.395620 -0.291693        0
# 2  0.129239 -0.010090        0
# 3  0.381917  0.964549        1
# 4 -0.870123  0.621002        1

# %%
sns.scatterplot(x='data1',y='data2',data=dataset,hue='Predict')
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %%
sns.scatterplot(x='data1',y='data2',data=dataset,hue=y)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>
